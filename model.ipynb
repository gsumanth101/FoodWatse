# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
data = pd.read_csv("food_wastage_data.csv")
data
# Out:
#      Type of Food  Number of Guests        Event Type  Quantity of Food  \
# 0            Meat               310         Corporate               450
# 1            Meat               400          Birthday               500
# 2      Vegetables               302          Birthday               371
# 3            Meat               491          Birthday               497
# 4            Meat               300         Corporate               400
# ...           ...               ...               ...               ...
# 1777  Baked Goods               310         Corporate               350
# 1778  Baked Goods               284  Social Gathering               443
# 1779       Fruits               220           Wedding               300
# 1780       Fruits               250           Wedding               350
# 1781  Baked Goods               400           Wedding               500
#
#      Storage Conditions Purchase History  Seasonality Preparation Method  \
# 0          Refrigerated          Regular  All Seasons             Buffet
# 1      Room Temperature          Regular       Winter             Buffet
# 2          Refrigerated          Regular       Summer             Buffet
# 3          Refrigerated          Regular  All Seasons        Finger Food
# 4          Refrigerated          Regular       Winter        Finger Food
# ...                 ...              ...          ...                ...
# 1777   Room Temperature          Regular       Summer        Finger Food
# 1778   Room Temperature          Regular       Winter             Buffet
# 1779   Room Temperature          Regular  All Seasons        Finger Food
# 1780   Room Temperature          Regular  All Seasons        Finger Food
# 1781   Room Temperature          Regular       Winter    Sit-down Dinner
#
#      Geographical Location   Pricing  Wastage Food Amount
# 0                    Urban       Low                   25
# 1                 Suburban      High                   40
# 2                 Suburban       Low                   27
# 3                    Rural      High                   32
# 4                    Urban  Moderate                   25
# ...                    ...       ...                  ...
# 1777                 Urban      High                   35
# 1778                 Rural       Low                   32
# 1779                 Urban  Moderate                   15
# 1780                 Rural  Moderate                   20
# 1781                 Rural      High                   45
#
# [1782 rows x 11 columns]

# %%
x = data.drop("Wastage Food Amount", axis=1)
y = data["Wastage Food Amount"]

# %%
numeric_features = x.select_dtypes(include=[np.number]).columns
categorical_features = x.select_dtypes(include=[object]).columns
numerical_pipeline = Pipeline([
    ('scaler', StandardScaler())
])
numerical_pipeline
# Out:
# Pipeline(steps=[('scaler', StandardScaler())])

# %%
categorical_pipeline = Pipeline([
    ('encoder', OneHotEncoder())
])
# Out:
# Index(['Type of Food', 'Event Type', 'Storage Conditions', 'Purchase History',
#        'Seasonality', 'Preparation Method', 'Geographical Location',
#        'Pricing'],
#       dtype='object')

# %%
x.columns
# Out:
# Index(['Type of Food', 'Number of Guests', 'Event Type', 'Quantity of Food',
#        'Storage Conditions', 'Purchase History', 'Seasonality',
#        'Preparation Method', 'Geographical Location', 'Pricing'],
#       dtype='object')

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_pipeline, numeric_features),
        ('cat', categorical_pipeline, categorical_features)
    ]
)

# %%
preprossed_x = preprocessor.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(preprossed_x, y, test_size=0.2, random_state=42)
# Out:
# array([[-0.5575043 , -0.93770669,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.14738238,  0.59635618,  0.        , ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.21212994,  1.36338762,  0.        , ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.21212994,  1.36338762,  0.        , ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.26256526, -0.17067526,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.26256526, -0.17067526,  0.        , ...,  0.        ,
#          0.        ,  1.        ]])

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# C:\Users\gsuma\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %%
model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.2785 - mae: 2.2160
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8453 - mae: 2.2157
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4928 - mae: 2.1345
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2429 - mae: 2.2522
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4757 - mae: 2.2111
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1731 - mae: 2.1089
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7049 - mae: 2.1536
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4680 - mae: 1.9891
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2694 - mae: 2.1067
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3993 - mae: 2.1711
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6241 - mae: 2.2299
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6314 - mae: 2.0440
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5367 - mae: 2.1156
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0046 - mae: 2.1127
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2081 - mae: 1.9721
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8065 - mae: 2.0216
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5051 - mae: 1.9972
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5605 - mae: 2.0457
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1777 - mae: 1.9738
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0833 - mae: 1.9828
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5156 - mae: 1.9810
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8837 - mae: 1.9193
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6789 - mae: 2.0123
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0508 - mae: 1.9405
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8543 - mae: 2.0194
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8567 - mae: 2.0113
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3032 - mae: 1.9713
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6070 - mae: 1.8601
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0054 - mae: 2.0384
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5523 - mae: 1.8738
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2546 - mae: 1.8466
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8791 - mae: 1.9195
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7160 - mae: 1.8798
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9576 - mae: 1.9364
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9031 - mae: 1.8986
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2980 - mae: 1.9428
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0067 - mae: 1.9210
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2529 - mae: 1.9163
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8963 - mae: 1.8032
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5029 - mae: 1.8667
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2813 - mae: 1.7728
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0461 - mae: 1.8006
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3106 - mae: 1.7951
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6278 - mae: 1.8560
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4368 - mae: 1.8338
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6545 - mae: 1.8252
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7994 - mae: 1.7484
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6815 - mae: 1.6739
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3359 - mae: 1.8348
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3252 - mae: 1.8536
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2831 - mae: 1.8087
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8322 - mae: 1.7420
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9605 - mae: 1.7211
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4281 - mae: 1.7945
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3487 - mae: 1.6697
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5290 - mae: 1.8441
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8679 - mae: 1.7402
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9019 - mae: 1.7366
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6673 - mae: 1.7248
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8825 - mae: 1.7576
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9047 - mae: 1.7260
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9030 - mae: 1.7225
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6989 - mae: 1.6795
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2564 - mae: 1.6401
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1835 - mae: 1.6383
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6142 - mae: 1.7354
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9823 - mae: 1.7616
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0514 - mae: 1.7761
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3904 - mae: 1.6765
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3500 - mae: 1.6384
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6864 - mae: 1.7088
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9465 - mae: 1.5554
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2328 - mae: 1.6161
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0289 - mae: 1.5545
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0248 - mae: 1.6016
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0266 - mae: 1.7763
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6030 - mae: 1.7260
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1453 - mae: 1.5911
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1270 - mae: 1.6254
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0800 - mae: 1.5768
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8195 - mae: 1.5747
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6914 - mae: 1.6948
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0573 - mae: 1.5939
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7258 - mae: 1.5574
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7507 - mae: 1.5560
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9416 - mae: 1.6033
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3513 - mae: 1.6094
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1090 - mae: 1.6040
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3133 - mae: 1.6015
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7033 - mae: 1.5086
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1771 - mae: 1.5830
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6242 - mae: 1.5167
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7966 - mae: 1.5331
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6594 - mae: 1.4974
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2971 - mae: 1.4591
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3254 - mae: 1.4840
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5055 - mae: 1.4838
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9848 - mae: 1.5879
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0087 - mae: 1.5235
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2082 - mae: 1.4219

# %%
model.evaluate(x_test, y_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.2443 - mae: 3.2553
# [22.28693962097168, 3.4524924755096436]

# %%
evaluation_result = model.evaluate(x_test, y_test)
if isinstance(evaluation_result, (list, tuple)):
    print(f"Test Loss: {evaluation_result[0]}, Test Accuracy: {evaluation_result[1]}")
else:
    print("Evaluation result is not a list or tuple.")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.5185
# Evaluation result is not a list or tuple.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam

model = Sequential([
    Dense(128, activation='relu', input_shape=(x_train.shape[1],), kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(1, activation='linear')
])


model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model.fit(x_train, y_train, validation_split=0.2, epochs=100, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# C:\Users\gsuma\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 920.2446 - val_loss: 934.7180
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 869.5230 - val_loss: 919.6942
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 820.3168 - val_loss: 888.2413
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 793.1920 - val_loss: 844.2399
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 736.7696 - val_loss: 791.8165
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 670.1818 - val_loss: 723.9698
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 640.3931 - val_loss: 654.4770
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 585.4434 - val_loss: 578.0690
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 489.5338 - val_loss: 506.0527
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 418.6509 - val_loss: 426.3850
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 363.2583 - val_loss: 351.8900
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 282.2663 - val_loss: 274.3473
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 231.5913 - val_loss: 205.0639
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 167.9241 - val_loss: 162.0412
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 158.7927 - val_loss: 125.0299
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 114.3247 - val_loss: 98.2042
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 91.8261 - val_loss: 79.3445
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 79.8359 - val_loss: 59.0675
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 78.2354 - val_loss: 47.8616
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 62.9266 - val_loss: 41.0962
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 67.4855 - val_loss: 39.2025
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 60.2036 - val_loss: 35.9000
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 64.4001 - val_loss: 35.2467
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 58.7486 - val_loss: 32.3094
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 58.5314 - val_loss: 32.8166
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 61.3274 - val_loss: 31.6283
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.8020 - val_loss: 30.3680
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.0260 - val_loss: 30.7851
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.5192 - val_loss: 29.9004
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.7081 - val_loss: 31.1295
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.6335 - val_loss: 30.0203
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 56.6868 - val_loss: 29.7155
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 50.3560 - val_loss: 29.6046
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 51.3365 - val_loss: 29.8778
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 51.4133 - val_loss: 29.9261
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.2450 - val_loss: 30.7981
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.6717 - val_loss: 31.7864
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 52.8789 - val_loss: 30.8454
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.1198 - val_loss: 31.1809
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.9592 - val_loss: 30.7072
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.9491 - val_loss: 29.2732
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 50.3517 - val_loss: 28.3312
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.7393 - val_loss: 28.9451
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 47.0438 - val_loss: 28.5460
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.0198 - val_loss: 28.1402
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 43.7196 - val_loss: 28.8611
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 51.5690 - val_loss: 27.7942
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52.9642 - val_loss: 27.6021
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.6132 - val_loss: 27.6212
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.4315 - val_loss: 26.7517
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.3236 - val_loss: 27.4970
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.9560 - val_loss: 27.2787
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.9788 - val_loss: 27.8015
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.8458 - val_loss: 28.7548
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 45.0689 - val_loss: 28.5310
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 45.7280 - val_loss: 28.4163
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 40.5813 - val_loss: 28.1811
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 42.3721 - val_loss: 28.8540
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 40.6686 - val_loss: 27.3020
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 42.2020 - val_loss: 28.6328

# %%
test_loss = model.evaluate(x_test, y_test)

print(f"Test Loss (MSE): {test_loss}")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.6165
# Test Loss (MSE): 23.14470100402832

# %%
sample_input = np.array([[0.1, 0.2, 0.3, 0.4, 1, 1, 1, 1, 1, 1]])
# Modify the input shape of the model to match the shape of the input data
prediction = model.predict(sample_input.reshape(1, -1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 sample_input = np.array([[0.1, 0.2, 0.3, 0.4, 1, 1, 1, 1, 1, 1]])
#       2 # Modify the input shape of the model to match the shape of the input data
# ----> 3 prediction = model.predict(sample_input.reshape(1, -1))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\input_spec.py:227, in assert_input_compatibility(input_spec, inputs, layer_name)
#     222     for axis, value in spec.axes.items():
#     223         if value is not None and shape[axis] not in {
#     224             value,
#     225             None,
#     226         }:
# --> 227             raise ValueError(
#     228                 f'Input {input_index} of layer "{layer_name}" is '
#     229                 f"incompatible with the layer: expected axis {axis} "
#     230                 f"of input shape to have value {value}, "
#     231                 "but received input with "
#     232                 f"shape {shape}"
#     233             )
#     234 # Check shape.
#     235 if spec.shape is not None:
#
# ValueError: Exception encountered when calling Sequential.call().
#
# Input 0 of layer "dense_3" is incompatible with the layer: expected axis -1 of input shape to have value 27, but received input with shape (1, 10)
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=(1, 10), dtype=float32)
#   • training=False
#   • mask=None
