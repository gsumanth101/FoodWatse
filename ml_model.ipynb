# %%
import numpy as np
import pandas as pd

data = pd.read_csv('food_wastage_data.csv')
data
# Out:
#      Type of Food  Number of Guests        Event Type  Quantity of Food  \
# 0            Meat               310         Corporate               450
# 1            Meat               400          Birthday               500
# 2      Vegetables               302          Birthday               371
# 3            Meat               491          Birthday               497
# 4            Meat               300         Corporate               400
# ...           ...               ...               ...               ...
# 1777  Baked Goods               310         Corporate               350
# 1778  Baked Goods               284  Social Gathering               443
# 1779       Fruits               220           Wedding               300
# 1780       Fruits               250           Wedding               350
# 1781  Baked Goods               400           Wedding               500
#
#      Storage Conditions Purchase History  Seasonality Preparation Method  \
# 0          Refrigerated          Regular  All Seasons             Buffet
# 1      Room Temperature          Regular       Winter             Buffet
# 2          Refrigerated          Regular       Summer             Buffet
# 3          Refrigerated          Regular  All Seasons        Finger Food
# 4          Refrigerated          Regular       Winter        Finger Food
# ...                 ...              ...          ...                ...
# 1777   Room Temperature          Regular       Summer        Finger Food
# 1778   Room Temperature          Regular       Winter             Buffet
# 1779   Room Temperature          Regular  All Seasons        Finger Food
# 1780   Room Temperature          Regular  All Seasons        Finger Food
# 1781   Room Temperature          Regular       Winter    Sit-down Dinner
#
#      Geographical Location   Pricing  Wastage Food Amount
# 0                    Urban       Low                   25
# 1                 Suburban      High                   40
# 2                 Suburban       Low                   27
# 3                    Rural      High                   32
# 4                    Urban  Moderate                   25
# ...                    ...       ...                  ...
# 1777                 Urban      High                   35
# 1778                 Rural       Low                   32
# 1779                 Urban  Moderate                   15
# 1780                 Rural  Moderate                   20
# 1781                 Rural      High                   45
#
# [1782 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# Type of Food             0
# Number of Guests         0
# Event Type               0
# Quantity of Food         0
# Storage Conditions       0
# Purchase History         0
# Seasonality              0
# Preparation Method       0
# Geographical Location    0
# Pricing                  0
# Wastage Food Amount      0
# dtype: int64

# %%
mappings = {}

for column in data.select_dtypes(include=['object']).columns:
    data[column] = data[column].astype('category')
    mappings[column] = dict(enumerate(data[column].cat.categories))
    data[column] = data[column].cat.codes

print(data.head())
print("\nMappings:\n")
for column, mapping in mappings.items():
    print(f"{column}: {mapping}")
# Out:
#    Type of Food  Number of Guests  Event Type  Quantity of Food  \
# 0             3               310           1               450
# 1             3               400           0               500
# 2             4               302           0               371
# 3             3               491           0               497
# 4             3               300           1               400
#
#    Storage Conditions  Purchase History  Seasonality  Preparation Method  \
# 0                   0                 1            0                   0
# 1                   1                 1            2                   0
# 2                   0                 1            1                   0
# 3                   0                 1            0                   1
# 4                   0                 1            2                   1
#
#    Geographical Location  Pricing  Wastage Food Amount
# 0                      2        1                   25
# 1                      1        0                   40
# 2                      1        1                   27
# 3                      0        0                   32
# 4                      2        2                   25
#
# Mappings:

# %%
data.shape
# Out:
# (1782, 11)

# %%
data.describe()
# Out:
#        Type of Food  Number of Guests   Event Type  Quantity of Food  \
# count   1782.000000       1782.000000  1782.000000       1782.000000
# mean       1.794613        317.804714     1.543771        411.125701
# std        1.354765         67.829658     1.073933         65.204674
# min        0.000000        207.000000     0.000000        280.000000
# 25%        1.000000        267.000000     1.000000        350.000000
# 50%        2.000000        302.000000     2.000000        400.000000
# 75%        3.000000        350.000000     2.000000        480.000000
# max        4.000000        491.000000     3.000000        500.000000
#
#        Storage Conditions  Purchase History  Seasonality  Preparation Method  \
# count         1782.000000       1782.000000  1782.000000         1782.000000
# mean             0.649270          0.884400     1.005051            1.270483
# std              0.477332          0.319835     0.839425            0.730205
# min              0.000000          0.000000     0.000000            0.000000
# 25%              0.000000          1.000000     0.000000            1.000000
# 50%              1.000000          1.000000     1.000000            1.000000
# 75%              1.000000          1.000000     2.000000            2.000000
# max              1.000000          1.000000     2.000000            2.000000
#
#        Geographical Location      Pricing  Wastage Food Amount
# count            1782.000000  1782.000000          1782.000000
# mean                1.093715     0.999439            28.536476
# std                 0.728558     0.869665            10.461317
# min                 0.000000     0.000000            10.000000
# 25%                 1.000000     0.000000            20.000000
# 50%                 1.000000     1.000000            26.500000
# 75%                 2.000000     2.000000            35.000000
# max                 2.000000     2.000000            63.000000

# %%
data.corr()
# Out:
#                        Type of Food  Number of Guests  Event Type  \
# Type of Food               1.000000         -0.027829    0.015059
# Number of Guests          -0.027829          1.000000   -0.003760
# Event Type                 0.015059         -0.003760    1.000000
# Quantity of Food          -0.006528          0.794401    0.024353
# Storage Conditions        -0.688851         -0.006053   -0.034111
# Purchase History          -0.189592          0.009544   -0.076802
# Seasonality                0.172731         -0.006491    0.026225
# Preparation Method         0.016458          0.143111    0.157450
# Geographical Location      0.012117          0.068440   -0.040050
# Pricing                   -0.004387         -0.406790   -0.033339
# Wastage Food Amount       -0.013892          0.650421    0.030344
#
#                        Quantity of Food  Storage Conditions  Purchase History  \
# Type of Food                  -0.006528           -0.688851         -0.189592
# Number of Guests               0.794401           -0.006053          0.009544
# Event Type                     0.024353           -0.034111         -0.076802
# Quantity of Food               1.000000           -0.047273         -0.011688
# Storage Conditions            -0.047273            1.000000          0.260204
# Purchase History              -0.011688            0.260204          1.000000
# Seasonality                   -0.005613           -0.102076         -0.052199
# Preparation Method             0.220788           -0.048244          0.035388
# Geographical Location          0.125557           -0.015222          0.085072
# Pricing                       -0.409757            0.018462         -0.034550
# Wastage Food Amount            0.638648           -0.029876          0.026936
#
#                        Seasonality  Preparation Method  Geographical Location  \
# Type of Food              0.172731            0.016458               0.012117
# Number of Guests         -0.006491            0.143111               0.068440
# Event Type                0.026225            0.157450              -0.040050
# Quantity of Food         -0.005613            0.220788               0.125557
# Storage Conditions       -0.102076           -0.048244              -0.015222
# Purchase History         -0.052199            0.035388               0.085072
# Seasonality               1.000000            0.061892               0.014833
# Preparation Method        0.061892            1.000000               0.152856
# Geographical Location     0.014833            0.152856               1.000000
# Pricing                  -0.014610           -0.115588              -0.027388
# Wastage Food Amount       0.016124            0.237519               0.085928
#
#                         Pricing  Wastage Food Amount
# Type of Food          -0.004387            -0.013892
# Number of Guests      -0.406790             0.650421
# Event Type            -0.033339             0.030344
# Quantity of Food      -0.409757             0.638648
# Storage Conditions     0.018462            -0.029876
# Purchase History      -0.034550             0.026936
# Seasonality           -0.014610             0.016124
# Preparation Method    -0.115588             0.237519
# Geographical Location -0.027388             0.085928
# Pricing                1.000000            -0.685755
# Wastage Food Amount   -0.685755             1.000000

# %%
data.corr()['Wastage Food Amount']
# Out:
# Type of Food            -0.013892
# Number of Guests         0.650421
# Event Type               0.030344
# Quantity of Food         0.638648
# Storage Conditions      -0.029876
# Purchase History         0.026936
# Seasonality              0.016124
# Preparation Method       0.237519
# Geographical Location    0.085928
# Pricing                 -0.685755
# Wastage Food Amount      1.000000
# Name: Wastage Food Amount, dtype: float64

# %%
x = data.drop('Wastage Food Amount', axis=1)
y = data['Wastage Food Amount']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (1425, 10) (357, 10) (1425,) (357,)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test, y_test)
# Out:
# 0.9290292746846187

# %%
from sklearn.metrics import *
mean_squared_error(y_test, y_pred)
r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
print(f"R2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Mean Squared Error: 7.3566687203585595
# R2 Score: 0.9290292746846187

# %%
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)
